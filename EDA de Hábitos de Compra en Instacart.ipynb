# %% [markdown]
# # ¡Hola Carlos! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# # ¡Hola Alejando, mucho gusto! 😁
# <div class="alert alert-block alert-info">
#
#
#
#
# Primero que todo, te pido perdón por reenviar el proyecto sin las modificaciones sugeridas anteriormente, pues los comentarios y correcciones que añadiste, no me aparecían una vez fue notificada la corrección y decidí reenviarlo, una vez más, con el fin de obtener el feedback.
#
# Evidentemente, Oriana Silva, horas más tarde, me pasó el proyecto con tus comentarios y sugerencias.
#
# Ya generé todos los cambios sugeridos por ti y agregué lo que me dijiste que debería agregar
#
# Gracias por tu tiempo y paciencia.
# ¡Feliz resto de semana!
# <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (3ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tranquilo Carlos, no hay problema 😊. Lo importante es que hiciste un excelente trabajo con los ajustes! Tu proyecto ahora cumple con todos los objetivos propuestos. Estoy seguro de que lo que aprendiste aquí te será muy útil más adelante.
#
# ¡Éxito en tu próximo sprint! 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-swarning">
# <b>Comentario General del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Carlos noté que en esta iteración no aparecen los comentarios que te hice anteriormente, esto puede pasar si no trabajas sobre el notebook que ya revisé y envías un nuevo archivo. **Recuerda que es necesario que mantener todos los comentarios en las diferentes iteraciones con el fin de poder hacer una trazabilidad de tu proyecto**
#
# Respecto a esta interación, has cumplido casi todos los objtivos del proyecto. Sin embargo, hay algunas preguntas que aún muestran los resultados esperados. Te deje comentarios para que puedas hacer los ajustes necesarios.
#
# Quedo atento a tu próxima iteración 🦾
#
# *Estado del Proyecto:* **No Aprobado**
#
# </div>

# %% [markdown]
# ------

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
import pandas as pd
from matplotlib import pyplot as plt # importar librerías

# %%
cart = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
product = pd.read_csv('/datasets/products.csv', sep=';')
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
departments = pd.read_csv('/datasets/departments.csv', sep=';')
order = pd.read_csv('/datasets/order_products.csv', sep=';')
# leer conjuntos de datos en los DataFrames

# %%
print("\n\n\n",cart)# mostrar información del DataFrame
print("\n\n\n",cart.describe(),"\n\n\n")
print(cart.info())
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# ...

# %%
print("\n\n\n",product)# mostrar información del DataFrame
print("\n\n\n",product.describe(),"\n\n\n")
print(product.info())
# Out:
#         product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
print("\n\n\n",aisles)# mostrar información del DataFrame
print("\n\n\n",aisles.describe(),"\n\n\n")
print(aisles.info())
# Out:
#       aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]
#
#
#
#           aisle_id
# count  134.000000
# mean    67.500000
# std     38.826537
# min      1.000000
# 25%     34.250000
# 50%     67.500000
# 75%    100.750000
# max    134.000000
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
# ...

# %%
print("\n\n\n",departments)# mostrar información del DataFrame
print("\n\n\n",departments.describe(),"\n\n\n")
print(departments.info())
# Out:
#      department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing
#
#
#
#         department_id
# count      21.000000
# mean       11.000000
# std         6.204837
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# ...

# %%
print("\n\n\n",order)# mostrar información del DataFrame
print("\n\n\n",order.describe(),"\n\n\n")
print(order.info())
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]
#
#
#
#             order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# ...

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# En primera instancia, los datos se encuentran normales. El almacenamiento de los datos indicaba un separador el cual generó una modificación de código para agregar: sep=";".
# Se aprecia que hay una relación entre los data sets los cuales se conectarán por medio de "order_id", "product_id", "department_id" y "aisle_id", haciendo uso de un join.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
print(cart.duplicated().sum())# Revisa si hay pedidos duplicados
print(product.duplicated().sum())
print(aisles.duplicated().sum())
print(departments.duplicated().sum())
print(order.duplicated().sum())

dup = cart[cart.duplicated()]
print(dup)
# Out:
# 15
# 0
# 0
# 0
# 0
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# order_dow & order_hour_of_day con los mismos valores, razón por la cual se pueden considerar duplicados pero los ID se encuentran normales, no existen duplicados.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

print(cart[cart["order_hour_of_day"]==2])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145      1373529   143518             8          1                  2
# 169      3129415   201917             4          1                  2
# 894      2672805   134969            41          0                  2
# 950       284735     8831             4          5                  2
# 1260     2537018     7543            23          1                  2
# ...          ...      ...           ...        ...                ...
# 477526   2592344    46860            38          3                  2
# 477624   1448965   201408             4          6                  2
# 477920   2668224   139740             3          6                  2
# 478126    852233    71024             1          4                  2
# 478321   1629284    54187            12          6                  2
#
#         days_since_prior_order
# 145                       30.0
# 169                        8.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# El resultado muestra que existe un total de 1004 de 478967 registros para compras realizadas a las 2 de la mañana.

# %%
# Elimina los pedidos duplicados
cart.drop_duplicates(inplace=True)

# %%
# Vuelve a verificar si hay filas duplicadas
print(cart.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
duplicados_id_order = cart[cart.duplicated(subset='order_id')]
print(duplicados_id_order)

duplicados_id_user = cart[cart.duplicated(subset='user_id')]
print(duplicados_id_user)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 109      2646057    20084             6          0                 13
# 354      2593694    65807            98          4                 21
# 379      2740290    87345             6          4                 14
# 729         7531    18130            17          1                  8
# 734      1500229   130466            18          3                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# En primera instancia, se puede entender que los duplicados se encontraban en la columna de Order_ID, los cuales fueron descatados en pasos anteriores, no obstante, hay ID de usuarios que se encuentran repetidos lo cual es completamente normal dado a que un usuario puede hacer recompras en una plataforma o pagina web.
# Cómo los ID de pedidos son valores únicos, no pueden haber duplicados dado que cada compra es única ya que es el registro de una transacción específica.

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(product.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
duplicados_aisle_id = product[product.duplicated(subset='aisle_id')]
print(duplicados_aisle_id)
# Out:
#        product_id                                       product_name  \
# 12             13                                  Saline Nasal Mist
# 19             20     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 29             30         Three Cheese Ziti- Marinara with Meatballs
# 33             34                               Peanut Butter Cereal
# 35             36  Traditional Lasagna with Meat Sauce Savory Ita...
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 12           11             11
# 19           98              7
# 29           38              1
# ...

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
product['product_name'] = product['product_name'].str.upper()
print(product['product_name'].head(25))
# Out:
# 0                            CHOCOLATE SANDWICH COOKIES
# 1                                      ALL-SEASONS SALT
# 2                  ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3     SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4                             GREEN CHILE ANYTIME SAUCE
# 5                                          DRY NOSE OIL
# 6                        PURE COCONUT WATER WITH ORANGE
# 7                     CUT RUSSET POTATOES STEAM N' MASH
# 8                     LIGHT STRAWBERRY BLUEBERRY YOGURT
# 9        SPARKLING ORANGE JUICE & PRICKLY PEAR BEVERAGE
# 10                                    PEACH MANGO JUICE
# 11                           CHOCOLATE FUDGE LAYER CAKE
# 12                                    SALINE NASAL MIST
# 13                       FRESH SCENT DISHWASHER CLEANER
# 14                             OVERNIGHT DIAPERS SIZE 6
# 15                        MINT CHOCOLATE FLAVORED SYRUP
# 16                                    RENDERED DUCK FAT
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes
duplicados_products_NaN = product[product.duplicated(subset='product_name')]
print("\n\n\nProductos con nulos\n\n\n")
print(duplicados_products_NaN)


duplicados_products_sin_NaN= product[product['product_name'].notna() & product.duplicated(subset='product_name')]
print("\n\n\nProductos sin valor NaN\n\n\n")
print(duplicados_products_sin_NaN.head(30))

#product = product.dropna(subset=['product_name'])#
# Out:
# Productos con nulos
#
#
#
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se identifica 1.257 valores nulos dentro de los nombres de los productos.
# 104 valores corresponden a valores normalizados que se encuentran repetidos pero con ID y departamentos completamentamente diferentes ¿Cúal podría ser la posible explicación de esto? Podría ser que el producto es exactamente el mismo pero de diferentes marcas. Como ejemplo, el producto "GREEN TEA WITH GINSENG AND HONEY" posee 2 ID y departamentos diferentes a pesar de que el nombre está escrito de la misma manera.
#
# Se sugiere eliminar los datos nulos para evitar cesgos.

# %% [markdown]
# ### `departments` data frame

# %%
print(departments.duplicated().sum())


 # Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
duplicados_dep = departments[departments.duplicated()]
print(duplicados_dep)# Revisa únicamente si hay IDs duplicadas de productos
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hay registros duplicados en ninguna de las dos columnas.
# Se revisa duplicados en general para garantizar que no hay columnas repetidas y, acto seguido, se revisa por ID.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(aisles.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
duplicados_aisles = aisles[aisles.duplicated()]
print(duplicados_aisles)# Revisa únicamente si hay IDs duplicadas de productos
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No se encuentran registros duplicados en ninguna de las dos columnas.
# Se revisa duplicados en general para garantizar que no hay columnas repetidas y, acto seguido, se revisa por ID.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(order.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
duplicados_col1 = order[order.duplicated(subset='order_id')]
print("\n\n\norder_id\n\n\n")
print(duplicados_col1)
print("\n\n\nValidación - order_id\n\n\n")
duplicados_col1_1 = order['order_id'].value_counts()
duplicados_col1_1 = duplicados_col1_1[duplicados_col1_1 > 1]
print(duplicados_col1_1)

duplicados_col2 = order[order.duplicated(subset='product_id')]
print("\n\n\nproduct_id\n\n\n")
print(duplicados_col2)
print("\n\n\nValidación - product_id\n\n\n")
duplicados_col1_1 = order['product_id'].value_counts()
duplicados_col1_1 = duplicados_col1_1[duplicados_col1_1 > 1]
print(duplicados_col1_1)
# Out:
# order_id
#
#
#
#          order_id  product_id  add_to_cart_order  reordered
# 367       2867619       48094                9.0          0
# 824        844425       39408               10.0          1
# 1124      3319857       37067               19.0          0
# 1258      1038788       12471               14.0          0
# 1303      2825714       44632               16.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4094961 rows x 4 columns]
#
#
#
# Validación - order_id
#
#
#
# 61355      127
# 3308010    115
# 2136777    108
# 171934     104
# 1959075     98
#           ...
# 1969639      2
# 146246       2
# 747496       2
# 2024875      2
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Como primer paso, generé una validación general para identificar datos duplicados, luego lo revisé por columna para descatar datos duplicados. En este caso realmente no se encuentran datos duplicados aunque las validaciones muestran que si existen duplicados.
# ¿Por qué? No existen duplicados porque por cada order_id hay una serie de productos comprados, por esta razón se repite el order_id.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
nulos_product = product[product['product_name'].isna()]
print(nulos_product)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se observan 1258 registros nulos en la columnna porduct_name del df product.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
nulos_product = product[product['product_name'].isna() & (product['aisle_id'] == 100)]
print(nulos_product)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se aprecian 1258 registros nulos en la columna product name con el filtro de id 100 en aisle_id

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
nulos_product = product[product['product_name'].isna() & (product['department_id'] == 21)]
print(nulos_product)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se aprecian 1258 registros nulos en la columna product name con el filtro de id 21 en department_id

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
ais=aisles[aisles['aisle_id'] == 100]
print(ais)


dep=departments[departments['department_id'] == 21]
print(dep)
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se puede observar que los valores nulos se deben a valores "perdidos" en el id 21 de departments y en el id 100 de aisles, los cuales explican los valores nulos del df product.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
product['product_name'] = product['product_name'].fillna('Unknow')
print("Validación: \n\n\n")
nulos_product = product[product['product_name']=='Unknow']
print(nulos_product)
# Out:
# Validación:
#
#
#
#        product_id product_name  aisle_id  department_id
# 37             38       Unknow       100             21
# 71             72       Unknow       100             21
# 109           110       Unknow       100             21
# 296           297       Unknow       100             21
# 416           417       Unknow       100             21
# ...           ...          ...       ...            ...
# 49552       49553       Unknow       100             21
# 49574       49575       Unknow       100             21
# 49640       49641       Unknow       100             21
# 49663       49664       Unknow       100             21
# 49668       49669       Unknow       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se realiza la modificación de los valores nulos con el fin de garantizar que posean el registro "Unknow". Al inicio de este apartado se identifican 1258 registros nulos los cuales concuerdan con los registros modificados.

# %% [markdown]
# ### `orders` data frame

# %%
nulos_cart = cart[cart['days_since_prior_order'].isna()]
print(nulos_cart)#Encuentra los valores ausentes
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
nulos_cart = cart[cart['days_since_prior_order'].isna() & (cart['order_number'] != 1)]
print(nulos_cart)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Al realizar el filtro de nulos en days_since_prior_order y la condicion diferente a 1 en el oder_number, se puede observar que los valores nulos corresponden a los pedidos generados por primera vez.

# %% [markdown]
# ### `order_products` data frame

# %%
nulos_order = order[order['add_to_cart_order'].isna()]
print(nulos_order) # Encuentra los valores ausentes
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?

maximo = order['add_to_cart_order'].max()
minimo = order['add_to_cart_order'].min()

print(f"Valor máximo de add_to_cart_order: {maximo}")
print(f"Valor máximo de add_to_cart_order: {minimo}")
# Out:
# Valor máximo de add_to_cart_order: 64.0
# Valor máximo de add_to_cart_order: 1.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se identifican 836 registros que contienen datos nulos. Los valores máximos y minimos de la columna add_to_cart_order son 64 y 1

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
nulos_order = order[order['add_to_cart_order'].isna()][['order_id', 'add_to_cart_order']]
print(nulos_order)
# Out:
#          order_id  add_to_cart_order
# 737       2449164                NaN
# 9926      1968313                NaN
# 14394     2926893                NaN
# 16418     1717990                NaN
# 30114     1959075                NaN
# ...           ...                ...
# 4505662   1800005                NaN
# 4511400   1633337                NaN
# 4517562    404157                NaN
# 4534112   1673227                NaN
# 4535739   1832957                NaN
#
# [836 rows x 2 columns]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?

### No hay forma de saberlo a la primera. Partamos de lo siguiente: El df order contiene las columnas order_id, product_id, add_to_cart_order, reordered.###
### En ese orden de ideas, estamos analizando la columna cuyos datos muestran las cantidades de producto generadas por cada order_id###
### Lo que significa qué no se puede determinar si son más de 64 productos, o menos del valor indicado.###
### Quizá se podría suponer que los valores nulos corresponden a valores por encima de 64 productos por orden, pero esto generaría un sesgo por falta de información###
### Para tratar de dar una "solución", se propone lo siguiente como alternativa:###
nulos = order[order["add_to_cart_order"].isna()]
conteo_nulos = nulos.groupby('order_id')['product_id'].count()
todos_mayor_64 = (conteo_nulos > 64).all()
print(f"¿Todos los pedidos con valores ausentes tienen más de 64 productos?: {todos_mayor_64}\n\n\n")
### Cómo es de esperarse, es falso lo que da un mayor respaldo a mi comentario###

# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
nulos_order = order[order['add_to_cart_order'].isna()][['order_id', 'add_to_cart_order']]
print(nulos_order)

# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
conteo = order.groupby('order_id')['product_id'].count()
print(conteo)
minimo = conteo.min()
maximo = conteo.max()

print(f"\n\n\nValor mínimo de product_id: {minimo}")
print(f"Valor máximo de product_id: {maximo}")
# Out:
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?: False
#
#
#
#          order_id  add_to_cart_order
# 737       2449164                NaN
# 9926      1968313                NaN
# 14394     2926893                NaN
# 16418     1717990                NaN
# 30114     1959075                NaN
# ...           ...                ...
# 4505662   1800005                NaN
# 4511400   1633337                NaN
# 4517562    404157                NaN
# 4534112   1673227                NaN
# 4535739   1832957                NaN
#
# [836 rows x 2 columns]
# order_id
# 4          13
# 9          15
# 11          5
# 19          3
# 20          8
#            ..
# 3421034    17
# 3421053     9
# 3421071     5
# 3421077     4
# 3421079     1
# Name: product_id, Length: 450046, dtype: int64
#
#
#
# Valor mínimo de product_id: 1
# Valor máximo de product_id: 127

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# *IMPORTANTE* Revisar el comentario generado en el paso anterior.
#
# Se observa que existen 127 como valor máximo y 1 como valor mínimo para product_id filtrando por valor único de pedido.
# 836 son el número total de registros nulos correspondientes partiendo de valor único de order_id

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order["add_to_cart_order"] = order["add_to_cart_order"].fillna("999")
order["add_to_cart_order"] = order["add_to_cart_order"].astype(int)
print("Validación: \n\n\n")

print(order[order["add_to_cart_order"]==999])
# Out:
# Validación:
#
#
#
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                999          0
# 9926      1968313       43867                999          0
# 14394     2926893       11688                999          0
# 16418     1717990        4142                999          0
# 30114     1959075       42828                999          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                999          0
# 4511400   1633337         260                999          0
# 4517562    404157        9517                999          0
# 4534112   1673227       17835                999          0
# 4535739   1832957       17949                999          1
#
# [836 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# El paso a paso era modificar los nulos por 999. Cómo la columna es tipo str, el 999 va con comillas " " para garantizar que se cumpla la condición de modificar una cadena con otra cadena. Acto seguido, se realiza el cambio de formato de str a int por medio del método *astype*.
# Se lleva a cabo la validación garantizando que los 836 registros iniciales se hayan modificado.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
# En el paso a paso solicitado, se aprecia una serie de valores nulos que afectan directamente a los datos.
# Se puede apreciar que las tablas son de tipo relacional y estás tienen un impacto directo entre ellas mismas ¿Cómo puedo determinar esto? Algunos valores nulos de los pedidos se relacionaba directamente por los valores "missing" que se podían observar en la tabla aisles y departments.
#
# Cabe resaltar qué algunos procesos de analítica y data wrangling para este proyecto se dificultan por falta de información dentro de las mismas tablas, tal como sucedio en el último procesamiento de este segmento.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
nulos = cart[~cart['order_hour_of_day'].between(0, 23)]
print(nulos)

minimo = cart['order_hour_of_day'].min()
maximo = cart['order_hour_of_day'].max()
print(f"\n\nValor mínimo: {minimo}")
print(f"Valor máximo: {maximo}")
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
#
#
# Valor mínimo: 0
# Valor máximo: 23

# %%
nulos = cart[~cart['order_dow'].between(0, 6)]
print(nulos)

minimo = cart['order_dow'].min()
maximo = cart['order_dow'].max()
print(f"\n\nValor mínimo: {minimo}")
print(f"Valor máximo: {maximo}")
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
#
#
# Valor mínimo: 0
# Valor máximo: 6

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Datos completamente normalizados dentro del rango correspondiente para cada columna y validados de dos formas diferentes.

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
order_hour = cart['order_hour_of_day'].value_counts().sort_index()
print(order_hour)

plt.figure(figsize=(10,6))
plt.bar(order_hour.index, order_hour.values, color='skyblue', edgecolor='black')

plt.title('Número de pedidos por hora del día')
plt.xlabel('Hora del día (0 a 23)')
plt.ylabel('Cantidad de pedidos')
plt.xticks(range(0, 24))  # Asegura que se muestren todas las horas
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# 0      3180
# 1      1763
# 2      1004
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
#
# A las 10:00 AM, se observan un total de 40.578 ordenes (Hora del día con mayores compras) y 4:00 AM se observa un total de 765 ordenes (Hora del día con menos compras)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Los valores son correctos. Sin embargo, recuerda que los seres humanos somos principalmente visuales. Por lo tanto, cuando manejes este tipo de información, una buena práctica es acompañarla de una gráfica. Esto facilita el estudio y el análisis de los datos.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (3ra Iteración)</b> <a class=“tocSkip”></a>
#
# Genial Carlos, ahora la información es más fácil de analizar
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
order_day = cart['order_dow'].value_counts().sort_index()
print(order_day)

plt.figure(figsize=(10,6))
plt.bar(order_day.index, order_day.values, color='skyblue', edgecolor='black')

plt.title('Número de pedidos cada día de la semana')
plt.xlabel("Días de la semana (0 a 6 → Domingo a Sábado)")
plt.ylabel('Cantidad de pedidos')
plt.xticks(range(0, 6))  # Asegura que se muestren todas las horas
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# 0    84090
# 1    82185
# 2    65833
# 3    60912
# 4    59810
# 5    63488
# 6    62649
# Name: order_dow, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
#
# El día domingo es el día con mayor cantidad de ordenes (84.090 ordenes) y el día jueves es el día con la menor cantidad de ordenes (59810 ordenes).

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Acá aplica el mismo comentario anterior. Siempre será mejor mostrar este tipo de datos con una gráfica que solo con la tabla
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (3ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo con los ajustes
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
minimo = cart["days_since_prior_order"].min()
maximo = cart["days_since_prior_order"].max()
print(f"Los clientes esperan un mínimo de {minimo} días después de su última compra.")
print(f"Los clientes esperan un máximo de {maximo} días después de su última compra.")

plt.figure(figsize=(10,6))
plt.hist(cart["days_since_prior_order"].dropna(), bins=30, color='skyblue', edgecolor='black')

plt.title('Distribución de días entre pedidos')
plt.xlabel('Días desde el pedido anterior')
plt.ylabel('Número de pedidos')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# Los clientes esperan un mínimo de 0.0 días después de su última compra.
# Los clientes esperan un máximo de 30.0 días después de su última compra.

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se observa que los clientes pueden esperar hasta 30 días para hacer una compra después de la última compra o puede que el mismo día hagan otra compra.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# En este caso los valores estadísticos que muestras se quedan cortos, ya que se está omitiendo información de los días intermedios. Para esta pregunta puedes usar un diagrama de barras para mostrar todos los valores desde el valor 0 hasta 30, estoy seguro que podrás identificar patrones particulares en los datos.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (3ra Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo obteniendo la gráfica, ésta permite ver patrones como compras semanales o mensuales.
#
# Muchos de los clientes hacen compras semanales (cada 7 días), y parece que una gran proporción de usuarios realiza compras mensuales (cada 30 días). Sin embargo, la tendencia decreciente en los últimos días podría indicar un error común al registrar los datos correspondientes al día 30, ya que, cuando no hay información disponible, algunos sistemas suelen asignar automáticamente el último valor de la serie de tiempo (última hora, último día de la semana, del mes o del año). Es un detalle importante a tener en cuenta para mejorar la precisión de los datos.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
miercoles = cart[cart['order_dow'] == 3]
sabado = cart[cart['order_dow'] == 6]

ordenes_miercoles = miercoles['order_hour_of_day'].value_counts().sort_index()
ordenes_sabado = sabado['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(12,6))
plt.bar(ordenes_miercoles.index - 0.2, ordenes_miercoles.values, width=0.4, label='Miércoles', color='skyblue')
plt.bar(ordenes_sabado.index + 0.2, ordenes_sabado.values, width=0.4, label='Sábado', color='wheat')
plt.xlabel('Hora del día')
plt.ylabel('Número de órdenes')
plt.title('Órdenes x Hora: Miércoles vs Sábado')
plt.xticks(range(0, 24))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
#
#
# Se observa que existe una fuerte tendencia de compra entre las 8:00 AM y 6:00 PM.
#
# El día sábado tiene una fuerte tendencia de compra entre las 11:00 AM y 5:00 PM con respecto al miércoles.
#
# Para el día míercoles, se ve una fuerte tendencia en ventas entre las 6:00 AM y las 10 AM con respecto al sábado.
#
# En términos generales, se puede determinar un mayor comportamiento de ventas para los días sábados en la mayor parte de las franjas horarias.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
pedidos_por_cliente = cart['user_id'].value_counts()

plt.figure(figsize=(10, 6))
plt.hist(pedidos_por_cliente, bins=30, color='mediumseagreen', edgecolor='black')
plt.xlabel('Número de pedidos por cliente')
plt.ylabel('Cantidad de clientes')
plt.title('Distribución de pedidos por cliente')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
#
# Los clientes tiene un comportamiento de compra entre uno a tres pedidos. La distibución de los datos conlleva a entender que existe una retención de clientes bastante moderada, pues los clientes que generan más de cuatro pedidos es bastante baja con respecto a los que vuelven a ordenar una o tres veces.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
top_20 = order['product_id'].value_counts().head(20).reset_index()
top_20.columns = ['product_id', 'order_count']

top_20 = top_20.merge(product[['product_id', 'product_name']], on='product_id')

top_20['label'] = top_20['product_name'] + ' (ID: ' + top_20['product_id'].astype(str) + ')'

top_20 = top_20.sort_values(by='order_count')

plt.figure(figsize=(10, 8))
plt.barh(top_20['label'], top_20['order_count'], color='mediumseagreen')
plt.xlabel('Número de órdenes')
plt.title('Top 20 productos más populares')
plt.tight_layout()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
# Existen cinco productos que se pueden considerar los más populares (cuatro veces ordenados por pedido), seguido por ocho productos (tres veces ordenados por pedido).
# Se puede determinar qué se deben generar un impulso de marketing y procesos de venta para aumentar y/o mejorar la cantidad de veces que se ordena los demás productos puesto que realmente las cantidades son muy bajas teniendo en cuenta la larga lista de productos existentes.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
productos_por_pedido = order.groupby('order_id')['product_id'].count()

plt.figure(figsize=(10,6))
plt.hist(productos_por_pedido, bins=50, color='skyblue', edgecolor='black')
plt.title('Distribución de productos por pedido')
plt.xlabel('Número de productos en un pedido')
plt.ylabel('Cantidad de pedidos')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
# Los usarios tienden a comprar alrededor de 10 productos por pedido. Ademas los usuarios suelen generar pedidos que tienen entre 7 y 12 artículos.
# Mayormente, los pedidos suelen contener 1 producto.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
reordenados = order[order['reordered'] >= 1]

top_reordenados = reordenados['product_id'].value_counts().head(20).reset_index()
top_reordenados.columns = ['product_id', 'reorder_count']

top_reordenados = top_reordenados.merge(product[['product_id', 'product_name']], on='product_id')

top_reordenados['label'] = top_reordenados['product_name'] + ' (ID: ' + top_reordenados['product_id'].astype(str) + ')'

plt.figure(figsize=(10, 8))
plt.barh(top_reordenados['label'], top_reordenados['reorder_count'], color='skyblue')
plt.xlabel('Veces reordenado')
plt.title('Top 20 productos más reordenados')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
# Se determina que los babanos, los paquetes de bananos orgánicos, fresas orgánicas y la espinaca bebé orgánica, son los productos mayormente comprados de nuevo. Lo anterior se puede traducir como un grado de satisfacción con respecto a estos productos.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
### Por favor, profesor o calificador, esta pregunta la lleve a cabo de esta forma después de investigar y revisar códigos por internet###
### para poder abordar la respuesta, pero no me siento muy seguro al respecto.###
### ¿Podrías indicarme, en caso dado de que este punto esté bien, ¿Cómo lo abordarías tu?###

# %%
agrupado = order.groupby('product_id')['reordered'].agg(['sum', 'count']).reset_index()
agrupado.columns = ['product_id', 'total_reordered', 'total_orders']

agrupado['reorder_ratio'] = agrupado['total_reordered'] / agrupado['total_orders']


agrupado = agrupado.merge(product[['product_id', 'product_name']], on='product_id')

filtrado = agrupado[agrupado['total_orders'] >= 100]

top_reordered = filtrado.sort_values(by='reorder_ratio', ascending=False).head(20)

plt.figure(figsize=(10,6))
plt.hist(filtrado['reorder_ratio'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Proporción de reordenamiento')
plt.ylabel('Número de productos')
plt.title('Distribución de proporciones de reordenamiento (productos con ≥ 100 pedidos)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
# Como podemos ver, existe una baja proporción de reordenamiento en los productos, en otras palabras, el consumo es bajo ya que no son comprados de forma recurrente. Además, se puede observar que existen productos que tienen una decisión de recompra en los pedidos generados después de la primera compra (Se determina por que tan cerca está el reordenamiento al valor de 1.0).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Aunque los cálculos son correcto, la gráfica que estás usando no es la más adecuada. Te recomiendo graficarlos en un histograma para visualizar su distribución y poder sacar conclusiones más claras sobre su comportamiento, analizando todos los datos y no solo el top 20
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo con los ajustes Carlos
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
order_prod_users = order.merge(cart[['order_id', 'user_id']], on='order_id')

user_total_orders = order_prod_users.groupby('user_id')['reordered'].count()
user_total_reorders = order_prod_users.groupby('user_id')['reordered'].sum()

user_reorder_rate = (user_total_reorders / user_total_orders).reset_index()
user_reorder_rate.columns = ['user_id', 'reorder_rate']

plt.figure(figsize=(10,6))
plt.hist(user_reorder_rate['reorder_rate'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribución de la proporción de productos reordenados por usuario')
plt.xlabel('Proporción de productos reordenados')
plt.ylabel('Número de usuarios')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
# Muchos clientes tienen ratios cercanos a 0.5 y 0.8, lo cual indica que hay comportamiento de re compra.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primeros = order[order['add_to_cart_order'] == 1]

primeros_counts = primeros['product_id'].value_counts().head(20).reset_index()
primeros_counts.columns = ['product_id', 'first_added_count']

top_first_added = primeros_counts.merge(product[['product_id', 'product_name']], on='product_id')

plt.figure(figsize=(12, 8))
plt.barh(top_first_added['product_name'], top_first_added['first_added_count'], color='skyblue')
plt.xlabel('Número de veces agregado primero')
plt.title('Top 20 productos más agregados primero al carrito')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Escribe aquí tus conclusiones*
#
# Los principales productos agregados primero al carrito son los bananos, bananos orgánicos, la leche, las fresas, los aguacates hass y la espinaca baby.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Aunque en muchas partes del proceso se sugiere mejorar el marketing y el proceso de ventas para algunos productos, se considera que existe un alto consumo y re compra por parte de los usuarios consumidores lo que da a entender que el negocio opera en excelentes condiciones.
# Es importante tener en cuenta que hay muchos artículos que son poco consumidos y no hay un gran numero de productos que se ordenan cuando los clientes vuelven a consumir, pues son pocos los clientes que logran ordenar más de 12 artículos por pedido o re compra.
# Se sugiere dar un mayor entendimiento a los productos cuyos nombres se encuentran repetidos para generar mayor contexto a la hora de entender el porqué están duplicados.
#
# En resumen, existe alguna "fidelización" con respecto a los usarios, pero se debe generar activación de algunos productos para mejorar la cantidad promedio de ventas de los productos que se consumen en menor cantidad.
